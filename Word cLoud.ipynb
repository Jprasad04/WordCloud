# %%
# !pip install wordcloud
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter

# Read the CSV file
df = pd.read_excel(r'C:\Users\janha\Downloads\Word_cloud.xlsx')

# Extract data from a specific column
column_name = 'Reviews_name'
text_data = ' '.join(df[column_name].dropna())

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Split text into words
words = text_data.split()

# Count the frequency of each word
word_freq = Counter(words)
print(word_freq)

# Plot the WordCloud

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\janha\appdata\roaming\python\python311\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Counter({'the': 27, 'is': 20, 'and': 11, 'this': 11, 'good': 9, 'I': 8, 'a': 8, 'phone': 7, 'it': 6, ',': 6, 'not': 6, 'The': 6, 'camera': 5, 'for': 5, 'screen': 5, 'its': 5, 'but': 5, 'with': 5, 'have': 5, 'you': 5, 'of': 4, 'are': 4, 'as': 4, 'very': 4, 'in': 4, 'my': 4, 'to': 4, 'price': 4, 'at': 4, 'like': 3, 'They': 3, 'display': 3, 'quality.': 3, 'on': 3, 'quality,': 3, 'average': 3, '5G': 3, 'quality': 3, 'than': 3, 'Redmi': 3, 'will': 3, 'experience': 3, 'looks': 2, 'good,': 2, 'sound': 2, 'from': 2, 'am': 2, 'user': 2, 'i': 2, '2': 2, 'hours': 2, '1.': 2, 'Battery': 2, 'big': 2, '(for': 2, 'me': 2, 'mobile': 2, '4.': 2, 'definitely': 2, 'better': 2, 'large': 2, 'sacrifice': 2, 'Good': 2, 'budget': 2, 'does': 2, 'all': 2, 'pro': 2, 'phones,': 2, 'about': 2, 'also': 2, 'Overall': 2, 'give': 2, "I'll": 2, 'rate': 2, 'Realme': 2, 'UI': 2, 'Customers': 1, 'appearance': 1, 'cellular': 1, 'phone.': 1, 'say': 1, 'design': 1, 'too': 1, 'outstanding.': 1, 'appreciate': 1, 'value,': 1, 'However,': 1, 'some': 1, 'customers': 1, 'dislike': 1, 'Opinions': 1, 'mixed': 1, 'charging,': 1, 'battery': 1, 'backup,': 1, 'performance.': 1, 'AI-generated': 1, 'text': 1, 'customer': 1, 'reviews': 1, 'writing': 1, 'review': 1, 'general': 1, 'install': 1, 'many': 1, 'apps': 1, 'view': 1, 'Your': 1, 'tube': 1, 'views': 1, 'day': 1, 'an': 1, 'average.': 1, 'PROs:': 1, 'performance': 1, 'amazing.': 1, '2.Camera': 1, 'above': 1, 'okay)': 1, '3.Network': 1, '-': 1, 'loved': 1, '1st': 1, 'time': 1, 'felt': 1, '.': 1, 'Its': 1, 'Superb': 1, 'Screen': 1, 'view.': 1, 'CONs:': 1, '1.Charging': 1, 'Time': 1, '(0': 1, '100%)': 1, 'supports': 1, '18W': 1, 'charging.': 1, '2.Large': 1, 'handy)': 1, '3.BLOTWARE': 1, 'one': 1, 'issue.': 1, 'Over': 1, 'ALL': 1, ':': 1, '4/5': 1, 'rating': 1, 'worth': 1, 'money.': 1, 'll': 1, 'keep': 1, 'short.': 1, 'has': 1, 'decent': 1, 'performance,': 1, 'that': 1, 'camera(Terrible': 1, 'areas': 1, 'confusing': 1, 'lighting)': 1, 'battery.': 1, 'main': 1, 'reason': 1, 'perfect': 1, "let's": 1, 'down': 1, 'speakers.': 1, 'quiet': 1, 'no': 1, 'Mostly': 1, 'speakers': 1, 'major': 1, 'Now': 1, 'mention': 1, 'points': 1, 'bad': 1, 'points.': 1, 'built': 1, '2.': 1, 'life': 1, '3.': 1, 'Looks': 1, 'great': 1, 'premium': 1, 'fone.': 1, 'memory': 1, 'space.': 1, 'Apart': 1, 'these': 1, 'more': 1, 'most': 1, 'aspects.': 1, 'But': 1, 'yes': 1, 'can': 1, 'range.': 1, 'range,': 1, 'your': 1, 'needs': 1, 'phone,': 1, 'Memory': 1, 'super,': 1, 'quite': 1, 'when': 1, 'compare': 1, 'only': 1, 'thing,': 1, 'though': 1, 'company': 1, 'says': 1, '50': 1, 'megapixel,': 1, "don't": 1, 'Camera': 1, 'pictures': 1, 'comming': 1, 'dark': 1, 'compared': 1, 'previous': 1, 'slower': 1, 'version': 1, 'take': 1, 'vedio,': 1, 'buy': 1, 'note': 1, 'versions,': 1, 'there': 1, 'display,': 1, 'notes': 1, 'get': 1, 'smaller': 1, 'this,......': 1, 'satisfied': 1, '7/10': 1, 'rating.............': 1, '3.5/5': 1, 'if': 1, 'talk': 1, '2/5': 1, 'rating,': 1, "I'd": 1, '3.5/5.': 1, 'My': 1, 'was': 1, 'far': 1, 'one.': 1, 'substandard,': 1, 'considering': 1, 'price.': 1, '(I': 1, 'got': 1, 'Xiaomi': 1, 'HyperOS': 1, 'update': 1, 'soon': 1, 'after': 1, 'bouth': 1, 'handset)': 1, 'cluttered': 1, 'laggy;': 1, 'nowhere': 1, 'near': 1, 'smooth': 1, 'been': 1, 'having': 1, '5': 1, '(Realme': 1, '2.0)': 1, 'almost': 1, 'four': 1, 'years': 1, 'straight.': 1})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

data = (r"C:\Users\janha\Downloads\Word_cloud.xlsx")
df=pd.read_excel(data)

column_name='Reviews_name'
text_data=' '.join(df[column_name].dropna())

wordcloud= WordCloud(width=800,height=400,background_color='white').generate(text_data)

word=text_data.split()

word_freq=Counter(word)
print(word_freq)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# Counter({'the': 27, 'is': 20, 'and': 11, 'this': 11, 'good': 9, 'I': 8, 'a': 8, 'phone': 7, 'it': 6, ',': 6, 'not': 6, 'The': 6, 'camera': 5, 'for': 5, 'screen': 5, 'its': 5, 'but': 5, 'with': 5, 'have': 5, 'you': 5, 'of': 4, 'are': 4, 'as': 4, 'very': 4, 'in': 4, 'my': 4, 'to': 4, 'price': 4, 'at': 4, 'like': 3, 'They': 3, 'display': 3, 'quality.': 3, 'on': 3, 'quality,': 3, 'average': 3, '5G': 3, 'quality': 3, 'than': 3, 'Redmi': 3, 'will': 3, 'experience': 3, 'looks': 2, 'good,': 2, 'sound': 2, 'from': 2, 'am': 2, 'user': 2, 'i': 2, '2': 2, 'hours': 2, '1.': 2, 'Battery': 2, 'big': 2, '(for': 2, 'me': 2, 'mobile': 2, '4.': 2, 'definitely': 2, 'better': 2, 'large': 2, 'sacrifice': 2, 'Good': 2, 'budget': 2, 'does': 2, 'all': 2, 'pro': 2, 'phones,': 2, 'about': 2, 'also': 2, 'Overall': 2, 'give': 2, "I'll": 2, 'rate': 2, 'Realme': 2, 'UI': 2, 'Customers': 1, 'appearance': 1, 'cellular': 1, 'phone.': 1, 'say': 1, 'design': 1, 'too': 1, 'outstanding.': 1, 'appreciate': 1, 'value,': 1, 'However,': 1, 'some': 1, 'customers': 1, 'dislike': 1, 'Opinions': 1, 'mixed': 1, 'charging,': 1, 'battery': 1, 'backup,': 1, 'performance.': 1, 'AI-generated': 1, 'text': 1, 'customer': 1, 'reviews': 1, 'writing': 1, 'review': 1, 'general': 1, 'install': 1, 'many': 1, 'apps': 1, 'view': 1, 'Your': 1, 'tube': 1, 'views': 1, 'day': 1, 'an': 1, 'average.': 1, 'PROs:': 1, 'performance': 1, 'amazing.': 1, '2.Camera': 1, 'above': 1, 'okay)': 1, '3.Network': 1, '-': 1, 'loved': 1, '1st': 1, 'time': 1, 'felt': 1, '.': 1, 'Its': 1, 'Superb': 1, 'Screen': 1, 'view.': 1, 'CONs:': 1, '1.Charging': 1, 'Time': 1, '(0': 1, '100%)': 1, 'supports': 1, '18W': 1, 'charging.': 1, '2.Large': 1, 'handy)': 1, '3.BLOTWARE': 1, 'one': 1, 'issue.': 1, 'Over': 1, 'ALL': 1, ':': 1, '4/5': 1, 'rating': 1, 'worth': 1, 'money.': 1, 'll': 1, 'keep': 1, 'short.': 1, 'has': 1, 'decent': 1, 'performance,': 1, 'that': 1, 'camera(Terrible': 1, 'areas': 1, 'confusing': 1, 'lighting)': 1, 'battery.': 1, 'main': 1, 'reason': 1, 'perfect': 1, "let's": 1, 'down': 1, 'speakers.': 1, 'quiet': 1, 'no': 1, 'Mostly': 1, 'speakers': 1, 'major': 1, 'Now': 1, 'mention': 1, 'points': 1, 'bad': 1, 'points.': 1, 'built': 1, '2.': 1, 'life': 1, '3.': 1, 'Looks': 1, 'great': 1, 'premium': 1, 'fone.': 1, 'memory': 1, 'space.': 1, 'Apart': 1, 'these': 1, 'more': 1, 'most': 1, 'aspects.': 1, 'But': 1, 'yes': 1, 'can': 1, 'range.': 1, 'range,': 1, 'your': 1, 'needs': 1, 'phone,': 1, 'Memory': 1, 'super,': 1, 'quite': 1, 'when': 1, 'compare': 1, 'only': 1, 'thing,': 1, 'though': 1, 'company': 1, 'says': 1, '50': 1, 'megapixel,': 1, "don't": 1, 'Camera': 1, 'pictures': 1, 'comming': 1, 'dark': 1, 'compared': 1, 'previous': 1, 'slower': 1, 'version': 1, 'take': 1, 'vedio,': 1, 'buy': 1, 'note': 1, 'versions,': 1, 'there': 1, 'display,': 1, 'notes': 1, 'get': 1, 'smaller': 1, 'this,......': 1, 'satisfied': 1, '7/10': 1, 'rating.............': 1, '3.5/5': 1, 'if': 1, 'talk': 1, '2/5': 1, 'rating,': 1, "I'd": 1, '3.5/5.': 1, 'My': 1, 'was': 1, 'far': 1, 'one.': 1, 'substandard,': 1, 'considering': 1, 'price.': 1, '(I': 1, 'got': 1, 'Xiaomi': 1, 'HyperOS': 1, 'update': 1, 'soon': 1, 'after': 1, 'bouth': 1, 'handset)': 1, 'cluttered': 1, 'laggy;': 1, 'nowhere': 1, 'near': 1, 'smooth': 1, 'been': 1, 'having': 1, '5': 1, '(Realme': 1, '2.0)': 1, 'almost': 1, 'four': 1, 'years': 1, 'straight.': 1})
